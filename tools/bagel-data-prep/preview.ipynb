# %%
import datasets

# %%
dataset = datasets.load_dataset("pufanyi/bagel-example", "t2i")

# %%
data = dataset["train"]

# %%
data[0]["captions"]
# Out:
# '{"caption": "A green towel with a few brushes and two bars of soap on top."}'
